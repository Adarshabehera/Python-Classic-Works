# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("Survey_AI.csv")

# %%
df.head(4)
# Out:
#    ID  Q1.AI_knowledge                                      Q2.AI_sources  \
# 0   1                8  Internet;Books/Scientific papers (physical/onl...
# 1   2                7                              Internet;Social media
# 2   3                5  Internet;Books/Scientific papers (physical/onl...
# 3   4                5                              Internet;Social media
#
#    Q2#1.Internet  Q2#2.Books/Papers  Q2#3.Social_media  Q2#4.Discussions  \
# 0              1                  1                  0                 0
# 1              1                  0                  1                 0
# 2              1                  1                  0                 0
# 3              1                  0                  1                 0
#
#    Q2#5.NotInformed  Q3#1.AI_dehumanization  Q3#2.Job_replacement  ...  \
# 0                 0                       1                     2  ...
# 1                 0                       2                     3  ...
# ...

# %%
df.tail(3)
# Out:
#     ID  Q1.AI_knowledge                                     Q2.AI_sources  \
# 88  89                9  Books/Scientific papers (physical/online format)
# 89  90                2                    I don't inform myself about AI
# 90  91                2                   Discussions with family/friends
#
#     Q2#1.Internet  Q2#2.Books/Papers  Q2#3.Social_media  Q2#4.Discussions  \
# 88              0                  1                  0                 0
# 89              0                  0                  0                 0
# 90              0                  0                  0                 1
#
#     Q2#5.NotInformed  Q3#1.AI_dehumanization  Q3#2.Job_replacement  ...  \
# 88                 0                       1                     1  ...
# 89                 1                       2                     4  ...
# 90                 0                       2                     4  ...
#
#     Q7.Utility_grade  Q8.Advantage_teaching  Q9.Advantage_learning  \
# ...

# %%
df.isna().sum()
# Out:
# ID                                      0
# Q1.AI_knowledge                         0
# Q2.AI_sources                           0
# Q2#1.Internet                           0
# Q2#2.Books/Papers                       0
# Q2#3.Social_media                       0
# Q2#4.Discussions                        0
# Q2#5.NotInformed                        0
# Q3#1.AI_dehumanization                  0
# Q3#2.Job_replacement                    0
# Q3#3.Problem_solving                    0
# Q3#4.AI_rulling_society                 0
# Q4#1.AI_costly                          0
# Q4#2.Economic_crisis                    0
# Q4#3.Economic_growth                    0
# Q4#4.Job_loss                           0
# Q5.Feelings                             0
# Q6.Domains                              0
# Q6#1.Education                          0
# Q6#2.Medicine                           0
# Q6#3.Agriculture                        0
# Q6#4.Constructions                      0
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Q1.AI_knowledge', 'Q2.AI_sources', 'Q2#1.Internet',
#        'Q2#2.Books/Papers', 'Q2#3.Social_media', 'Q2#4.Discussions',
#        'Q2#5.NotInformed', 'Q3#1.AI_dehumanization', 'Q3#2.Job_replacement',
#        'Q3#3.Problem_solving', 'Q3#4.AI_rulling_society', 'Q4#1.AI_costly',
#        'Q4#2.Economic_crisis', 'Q4#3.Economic_growth', 'Q4#4.Job_loss',
#        'Q5.Feelings', 'Q6.Domains', 'Q6#1.Education', 'Q6#2.Medicine',
#        'Q6#3.Agriculture', 'Q6#4.Constructions', 'Q6#5.Marketing',
#        'Q6#6.Administration', 'Q6#7.Art', 'Q7.Utility_grade',
#        'Q8.Advantage_teaching', 'Q9.Advantage_learning',
#        'Q10.Advantage_evaluation ', 'Q11.Disadvantage_educational_process',
#        'Q12.Gender', 'Q13.Year_of_study', 'Q14.Major', 'Q15.Passed_exams',
#        'Q16.GPA'],
#       dtype='object')

# %%
## Correlation Questions :-

plot = sns.regplot(data = df[['Q16.GPA','Q7.Utility_grade']], x = 'Q16.GPA', y = 'Q7.Utility_grade')

plt.set(xlabel = 'Student GPA', ylabel = 'AI Utilization in Student Sector', title = 'Student GPA VS AI Utilization Data')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-ba80b171c553> in <cell line: 5>()
#       3 plot = sns.regplot(data = df[['Q16.GPA','Q7.Utility_grade']], x = 'Q16.GPA', y = 'Q7.Utility_grade')
#       4
# ----> 5 plt.set(xlabel = 'Student GPA', ylabel = 'AI Utilization in Student Sector', title = 'Student GPA VS AI Utilization Data')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'set'

# %%
plot = sns.lineplot(data = df[['Q15.Passed_exams','Q7.Utility_grade']], x = 'Q15.Passed_exams', y = 'Q7.Utility_grade')

plot.set(xlabel = 'Exam passed by Students',ylabel = 'AI Utility in Studies', xtitle = 'AI Utilization in passing the Exams')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-b3c52c360ed6> in <cell line: 3>()
#       1 plot = sns.lineplot(data = df[['Q15.Passed_exams','Q7.Utility_grade']], x = 'Q15.Passed_exams', y = 'Q7.Utility_grade')
#       2
# ----> 3 plot.set(xlabel = 'Exam passed by Students',ylabel = 'AI Utility in Studies', xtitle = 'AI Utilization in passing the Exams')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in <lambda>(self, **kwargs)
#     145             return
#     146
# --> 147         cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     148         cls.set.__name__ = "set"
#     149         cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in set(self, **kwargs)
#    1229         # Artist._update_set_signature_and_docstring() at the end of the
# ...

# %%
df.nunique()
# Out:
# ID                                      91
# Q1.AI_knowledge                         10
# Q2.AI_sources                           13
# Q2#1.Internet                            2
# Q2#2.Books/Papers                        2
# Q2#3.Social_media                        2
# Q2#4.Discussions                         2
# Q2#5.NotInformed                         2
# Q3#1.AI_dehumanization                   5
# Q3#2.Job_replacement                     5
# Q3#3.Problem_solving                     5
# Q3#4.AI_rulling_society                  5
# Q4#1.AI_costly                           5
# Q4#2.Economic_crisis                     5
# Q4#3.Economic_growth                     4
# Q4#4.Job_loss                            5
# Q5.Feelings                              4
# Q6.Domains                              44
# Q6#1.Education                           2
# Q6#2.Medicine                            2
# Q6#3.Agriculture                         2
# Q6#4.Constructions                       2
# ...

# %%
plot = sns.barplot(data=df[['Q14.Major', 'Q7.Utility_grade']],
                       x='Q14.Major', y='Q7.Utility_grade')
plot.set(xlabel='Major', ylabel='AI Utility in Education',
        title='Perceived AI Utility in Education vs Student Major')
plot.set_xticklabels(['Economic Cybernetics', 'Statistics and Economic Forecasting',
                    'Economic Informatics'], rotation=45)
# Out:
# [Text(0, 0, 'Economic Cybernetics'),
#  Text(1, 0, 'Statistics and Economic Forecasting'),
#  Text(2, 0, 'Economic Informatics')]

# %%
df.columns
# Out:
# Index(['ID', 'Q1.AI_knowledge', 'Q2.AI_sources', 'Q2#1.Internet',
#        'Q2#2.Books/Papers', 'Q2#3.Social_media', 'Q2#4.Discussions',
#        'Q2#5.NotInformed', 'Q3#1.AI_dehumanization', 'Q3#2.Job_replacement',
#        'Q3#3.Problem_solving', 'Q3#4.AI_rulling_society', 'Q4#1.AI_costly',
#        'Q4#2.Economic_crisis', 'Q4#3.Economic_growth', 'Q4#4.Job_loss',
#        'Q5.Feelings', 'Q6.Domains', 'Q6#1.Education', 'Q6#2.Medicine',
#        'Q6#3.Agriculture', 'Q6#4.Constructions', 'Q6#5.Marketing',
#        'Q6#6.Administration', 'Q6#7.Art', 'Q7.Utility_grade',
#        'Q8.Advantage_teaching', 'Q9.Advantage_learning',
#        'Q10.Advantage_evaluation ', 'Q11.Disadvantage_educational_process',
#        'Q12.Gender', 'Q13.Year_of_study', 'Q14.Major', 'Q15.Passed_exams',
#        'Q16.GPA'],
#       dtype='object')

# %%
## Getting the percentage of AI workings or use in the study Purposes :-

# Getting count of AI info sources
source_sum = pd.DataFrame(df[['Q2#1.Internet', 'Q2#2.Books/Papers',
                              'Q2#3.Social_media', 'Q2#4.Discussions',
                              'Q2#5.NotInformed']].sum())


# Getting percentage of sample size
sample_size = source_sum[0].sum()


# Getting percentage column
source_sum[1] = source_sum[0] / sample_size * 100

# %%
import matplotlib.ticker as mtick

ax = sns.barplot(data=source_sum, x=source_sum.index, y=source_sum.columns[1])
ax.set(xlabel='Sources of AI Information', ylabel='Percentage of Students',
      title='Percentage of Students Getting Information About AI from Different Sources')
ax.set_xticklabels(['Internet', 'Books/Papers', 'Social Media', 'Discussion',
                      'Uninformed'], rotation=45)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())

# %%
sentiments = df['Q5.Feelings'].value_counts()

# %%
sentiments
# Out:
# 1    62
# 2    12
# 3    10
# 4     7
# Name: Q5.Feelings, dtype: int64

# %%
df['Q5.Feelings'].nunique()
# Out:
# 4

# %%
### Showing the sentiments of Using the AI tools for the different Works :-

labels = ['Curiosity', 'Fear', 'Indifference', 'Trust']
plt.pie(sentiments, labels=labels, autopct='%1.1f%%')
plt.title('Feeling of AI in day to day life with  Certainty')
plt.show()

# %%
df.columns
# Out:
# Index(['ID', 'Q1.AI_knowledge', 'Q2.AI_sources', 'Q2#1.Internet',
#        'Q2#2.Books/Papers', 'Q2#3.Social_media', 'Q2#4.Discussions',
#        'Q2#5.NotInformed', 'Q3#1.AI_dehumanization', 'Q3#2.Job_replacement',
#        'Q3#3.Problem_solving', 'Q3#4.AI_rulling_society', 'Q4#1.AI_costly',
#        'Q4#2.Economic_crisis', 'Q4#3.Economic_growth', 'Q4#4.Job_loss',
#        'Q5.Feelings', 'Q6.Domains', 'Q6#1.Education', 'Q6#2.Medicine',
#        'Q6#3.Agriculture', 'Q6#4.Constructions', 'Q6#5.Marketing',
#        'Q6#6.Administration', 'Q6#7.Art', 'Q7.Utility_grade',
#        'Q8.Advantage_teaching', 'Q9.Advantage_learning',
#        'Q10.Advantage_evaluation ', 'Q11.Disadvantage_educational_process',
#        'Q12.Gender', 'Q13.Year_of_study', 'Q14.Major', 'Q15.Passed_exams',
#        'Q16.GPA'],
#       dtype='object')

# %%
df.head(3)
# Out:
#    ID  Q1.AI_knowledge                                      Q2.AI_sources  \
# 0   1                8  Internet;Books/Scientific papers (physical/onl...
# 1   2                7                              Internet;Social media
# 2   3                5  Internet;Books/Scientific papers (physical/onl...
#
#    Q2#1.Internet  Q2#2.Books/Papers  Q2#3.Social_media  Q2#4.Discussions  \
# 0              1                  1                  0                 0
# 1              1                  0                  1                 0
# 2              1                  1                  0                 0
#
#    Q2#5.NotInformed  Q3#1.AI_dehumanization  Q3#2.Job_replacement  ...  \
# 0                 0                       1                     2  ...
# 1                 0                       2                     3  ...
# 2                 0                       2                     1  ...
#
#    Q7.Utility_grade  Q8.Advantage_teaching  Q9.Advantage_learning  \
# ...

# %%
informed = df.groupby(['Q2#5.NotInformed']).mean()
informed_utility = pd.DataFrame(informed['Q7.Utility_grade'])
informed_utility['Utility_Percentage'] = informed['Q7.Utility_grade'].apply(lambda x : x * 10)
informed_utility['Utility_Percentage*1000'] =  informed['Q7.Utility_grade'].apply(lambda x:x *1000)
# Out:
# <ipython-input-49-3f5ec145fd39>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   informed = df.groupby(['Q2#5.NotInformed']).mean()

# %%
informed_utility
# Out:
#                   Q7.Utility_grade  Utility_Percentage  \
# Q2#5.NotInformed
# 0                         7.576471           75.764706
# 1                         5.500000           55.000000
#
#                   Utility_Percentage*1000
# Q2#5.NotInformed
# 0                             7576.470588
# 1                             5500.000000

# %%
sentiment = sns.barplot(data = informed_utility, x = informed_utility.index, y = 'Q7.Utility_grade')
sentiment.set(xlabel = 'informed_utility', ylabel = 'Q7.Utility_grade', title = 'Sentiment_of_AI_on_the_study')
sentiment.x_tickslabel(['Is_informed', 'Is_not_informed'], rotation = 45)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-46d87d920c2a> in <cell line: 3>()
#       1 sentiment = sns.barplot(data = informed_utility, x = informed_utility.index, y = 'Q7.Utility_grade')
#       2 sentiment.set(xlabel = 'informed_utility', ylabel = 'Q7.Utility_grade', title = 'Sentiment_of_AI_on_the_study')
# ----> 3 sentiment.x_tickslabel(['Is_informed', 'Is_not_informed'], rotation = 45)
#
# AttributeError: 'Axes' object has no attribute 'x_tickslabel'
